# %% [markdown]
# <a href="https://colab.research.google.com/github/uvadmt/uvadmt.github.io/blob/main/cs2120_psomega.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem Set &omega;

# %% [markdown]
# **This problem set is "Optional" - see details below.**
# Due: <b>8:29pm</b> on <b>Thursday, 20 March</b>.</p>

# %% [markdown]
# Discrete Math can sometimes feel very abstract and extremely theoretical, and although the skills and perspective we hope you are building in this class are broadly useful no matter what you end up doing, we know most students in this class are Computer Science majors so seeing a more direct connection to programming might be useful.
#
# For this problem set, we want you to apply some of the techniques that you've learned, and implement them in Python code! As one caveat that we hope
# you'll always remember, though, nothing we can do in a physical computer is a close match to the things we can do with abstract mathematical objects-nothing in a physical computer can be infinite, there are no real numbers and none of the approximations we can implement behave like proper mathematical numbers, and every time we do anything it consumes energy and generates heat so cost matters (whereas in math, operations have no cost).
#
# This assignment is **optional**. We will determine your final grade without considering this PS, and then based on what you've done on this PS, we may (or may not) increase your course grade. We believe this assignment is beneficial to your development as a Computer Scientist, and there is no risk that submitting something for this assignment will have a negative impact on your course grade.
#
# There are three main parts (subsets of problems) to this problem set. If you complete Part 1 successfully, you'll receive a bonus comparable to about 10 test points (where a test is normalized to have 100 points); if you complete Part 1 and Part 2 well, you'll receive an effective bonus around 20 test points; if you complete all three parts well, your bonus could be 30 points or more.
#
#
# **Collaboration Policy:** For this assignment, you may work on your own or work with up to three other students. If you work with others on this assignment, your effective bonus will be divided by the square root of the number of students working together.
#
# You are welcome to use any resources you want to complete this assignment, and we do encourage you to use AI tools like ChatGPT or Claude or DeepSeek R1 (so long as you follow the Virginia regulations about not running R1 over state-owned networks which includes UVA networks). If you get help from an AI tool, you should include this as a comment directly in the code you write and include a URL that links to a transcript of your interactions. You should, of course, not blindly accept any output generated by these tools, but should check it carefully and make sure you understand it.

# %% [markdown]
# **Collaborators:** If you work with other students on this assignment, you should list everyone's name and UVA Id here, as well as in the submission form.

# %%
collaborators = [
    # TODO: list your collaborators as pairs of strings, with their name and UVA Id
    # e.g.:
    # ("John Backus", "jwb5d"), ("Barbara Liskov", "brb2a"), ("Bertrand Russell", "barh7j")
]

# %% [markdown]
# ## Introduction to Jupyter Notebooks and Google Colab

# %% [markdown]
# A Jupyter notebook, denoted by the `.ipynb` file extension, is an interactive document that combines text (written in Markdown format) with executable Python code.
#
# For this problem set, we are providing a notebook in Google Colab which allows you to run a Jupyter notebook in the cloud without needing to install anything on your computer. If you have experience using Jupyter on your own and prefer to use some other tool locally, that's fine. You can just download this file and use it with your favorite tool, but if you don't already have this experience, it will be easier to just work on the notebook with your web browser inside Google Colab and not need to install anything. Colab notebooks can be saved directly to a Google Drive, ensuring your progress is automatically saved and easily accessible from anywhere.

# %% [markdown]
# **Getting Started with Google Colab**
#
# To get started, make your own copy of this notebook: `File -> Save a copy in Drive`.

# %% [markdown]
# ## Organization of Jupyter Notebooks
#
# A notebook is organized into cells. There are two main types of cells:
#
# 1. Code cells: Where you write and execute Python code.
# 2. Text cells: Where you write formatted text, such as instructions, descriptions, or equations, using Markdown syntax.
#
# **Running Cells:**
#    - To run a cell, click on it and press *Shift + Enter* or click the play button on the left side of the cell.
#    - After you run a cell, you will see the output below the cell. Any variables defined will be available in later cells, but will only update when you re-run the cell.
#
# **Saving Your Work:** Your notebook is automatically saved to your Google Drive. To obtain a file of your notebook, select: 'File > Download > Download .ipynb*'.

# %% [markdown]
# # Part 1: Defining the Natural Numbers

# %% [markdown]
# First, let's make sure you remembered to **make your own copy of the notebook** and understand how to edit and run code in Jupyter.
#
# **Problem 0.** Edit the code cell below to print out something exciting about your Spring break, and run the cell to see the output.

# %%
print("Welcome to Jupyter!")
# TODO: Add a print statement to share something you’re excited
# to do during Spring Break.

# WARNING: Make sure that you have saved a copy of this notebook,
# and you are modifying the copy. Then run the cell to verify
# that it prints as expected.

# %% [markdown]
# ## Defining the Natural Numbers

# %% [markdown]
# Python provides quite good number types, including a reasonably good `int` type for representing an approximation to the Integers. Instead of using those, though, you will implement a set theoretic definition of the natural numbers using provided set-like types in Python.
#
# You will utilize the **frozenset** type in Python. Python also provides a **set** type, which is a _mutable_ set, but the immutable **frozenset** type is more like a mathematical set. For documentation on the **frozenset** type, see [the Python documentation](https://docs.python.org/3/library/stdtypes.html#set-types-set-frozenset) or try [asking your favorite AI tool](https://poe.com/s/bbGE0AScmePFYJLiYBEN).
#
# Your goal is to implement a natural number type in Python that is similar to the one we defined in class:
#
# - "$0$" $= \emptyset$.
# - $\textit{successor}(n) := n \cup \{n\}$.

# %% [markdown]
# To help with this, we've provided the function below to return a string representation of a set (including sets of sets). You don't need to understand this code, but can use the `zf_stringify` function to get a string that represents a set using our standard notation.

# %%
def zf_stringify(s):
    """
    Nicely returns a string corresponding to the input set.
    You should not need to modify this function.
    """
    def stringify_helper(s):
        if len(s) == 0:
            return '∅'
        return '{' + ",".join(stringify_helper(x) for x in s) + '}'
    return stringify_helper(s)

# %% [markdown]
# **Problem 1.1**: Define a variable that represents zero.

# %%
zf_zero = # TODO: Fill in this value

# %% [markdown]
# If your definition is correct, the following code should run with no assertion failures.

# %%
assert (len(zf_zero) == 0)
assert (zf_stringify(zf_zero) == '∅')

# %% [markdown]
# **Problem 1.2.** Define the _successor_ function.

# %%
def zf_successor(n):
    """
    Computes the successor of a set representation of a natural number.
    n ∪ {n}

    Parameters:
    n (frozenset): A set representation of a natural number.

    Returns:
    frozenset: The successor of n.
    """
    pass # TODO: Replace with your implementation of successor.

# %% [markdown]
# After you have successfully implemented `zf_successor` you should be able to run the code below with no assertion failures and see:
# ````
# "1": {∅}
# "2": {∅,{∅}}
# "3": {∅,{∅},{∅,{∅}}}
# "4": {∅,{∅,{∅},{∅,{∅}}},{∅},{∅,{∅}}}
# ````

# %%
zf_one = zf_successor(zf_zero)
print('"1": ' + zf_stringify(zf_one))
assert (type(zf_one) == frozenset)
assert (len(zf_one) == 1)
assert (zf_stringify(zf_one) == "{∅}")

zf_two = zf_successor(zf_one)
print('"2": ' + zf_stringify(zf_two))
assert (type(zf_two) == frozenset)
assert (len(zf_two) == 2)
assert (zf_stringify(zf_two) == "{∅,{∅}}")

zf_three = zf_successor(zf_two)
print('"3": ' + zf_stringify(zf_three))
assert (len(zf_three) == 3)
assert (zf_stringify(zf_three) == "{∅,{∅},{∅,{∅}}}")

zf_four = zf_successor(zf_three)
print('"4": ' + zf_stringify(zf_four))
assert (len(zf_four) == 4)
assert (zf_stringify(zf_four) == "{∅,{∅,{∅},{∅,{∅}}},{∅},{∅,{∅}}}")

print("All tests passed! 🥳")

# %% [markdown]
# ## Operations on the Natural Numbers

# %% [markdown]
# **Problem 1.3**: Implement a less than comparator for the natural numbers.
#
# You may **not** use the `len` operation, which would give you the cardinality of the frozenset. The only frozenset operation you should use is the [membership operation](https://poe.com/s/B7xIkOZWOBGsMY6nvWmW), `in`.

# %%
def zf_less_than(a, b):
    """
    Determines whether one natural number is less than another.

    Parameters:
    a: A set representation of a natural number.
    b: A set representation of another natural number.

    Returns:
    True if a is less than b, otherwise False.
    """
    # TODO: Replace with your implementation
    pass

# %% [markdown]
# If you have correctly implemented `zf_less_than`, the following code should run without errors.

# %%
# If zf_less_than is implemented correctly, this should run without errors
save_len = len
def len(s): print("You aren't allowed to use len!")

assert zf_less_than(zf_two, zf_three)
assert zf_less_than(zf_zero, zf_four)
assert not zf_less_than(zf_zero, zf_zero)
assert not zf_less_than(zf_four, zf_four)
assert not zf_less_than(zf_three, zf_two)

len = save_len # restore the normal len

print("All tests passed! 🥳")

# %% [markdown]
# **Problem 1.4:** Implement `zf_greater_than` and `zf_equal`.
#
# You should be able to do this without using anything other than `zf_less_than` and builtin python logical operators.

# %%
def zf_greater_than(a, b):
    """
    Determines whether one natural number is greater than another.

    Parameters:
    a: A set representation of a natural number.
    b: A set representation of another natural number.

    Returns:
    True if a is greater than b, otherwise False.
    """
    # TODO: Replace with your implementation
    pass

def zf_equal(a, b):
    """
    Determines if two natural numbers are equal.

    Parameters:
    a: A set representation of a natural number.
    b: A set representation of another natural number.

    Returns:
    True if a is equal than b, otherwise False.
    """
    # TODO: Replace with your implementation
    pass

# %% [markdown]
# After you have implemented `zf_greater_than` and `zf_equal` correctly, the following code should run without error.

# %%
save_len = len
def len(s): print("You aren't allowed to use len!")

assert zf_equal(zf_zero, zf_zero)
assert zf_equal(zf_one, zf_successor(zf_zero))
assert zf_equal(zf_successor(zf_one), zf_two)
assert zf_equal(zf_four, zf_four)
assert not zf_equal(zf_four, zf_three)
assert not zf_equal(zf_three, zf_four)


assert zf_greater_than(zf_three, zf_two)
assert zf_greater_than(zf_four, zf_zero)
assert not zf_greater_than(zf_zero, zf_zero)
assert not zf_greater_than(zf_four, zf_four)
assert not zf_greater_than(zf_two, zf_three)

len = save_len # restore the normal len

print("All tests passed! 🥳")

# %% [markdown]
# ## Generating "all" the Naturals
#
# We have provided some code below that generates all the natural numbers (at least as many as we can until Google's server blows up). You are not expected to modify this code, but should understand how it works and be able to use it.

# %%
def all_naturals():
  """ Generator for producing all natural numbers, starting from 0. """
  n = zf_zero
  while True:
    yield n
    n = zf_successor(n)

# %% [markdown]
# The result of calling `all_naturals()` is a generator object, that provides the `next` operation. Each time we call `next` we get the result of the next `yield` inside the generator definition. Try playing with the example code below to make sure you understand how the generator works.

# %%
nats = all_naturals()
print(zf_stringify(next(nats)))
print(zf_stringify(next(nats)))
print(zf_stringify(next(nats)))
print(zf_stringify(next(nats)))

# %%
# WARNING: before running this, make sure you know how to interrupt a notebook execution! (Under the Runtime menu. Interrupt Execution)
for n in all_naturals():
  print(zf_stringify(n))

# %% [markdown]
# ## Predecessor
#
# **Problem 1.5:** Implement a predecessor function. We have provided starting code for this, and you should only have to modify the line marked #TODO.

# %%
def zf_predecessor(n):
    """
    Returns the predecessor of a natural number in its set representation.

    Parameters:
    n: A set representation of a nonzero natural number.

    Returns:
    The predecessor of n in its set representation.
    """
    assert not zf_equal(n, zf_zero) # Predecessor is not defined for 0.
    for p in all_naturals():
      if True: # TODO: replace the if predicate to correctly define predecessor
        return p

# %% [markdown]
# If your definition of `zf_predecessor` is correct, the following code should execute without assertion failures.

# %%
assert(zf_equal(zf_predecessor(zf_one), zf_zero))
assert(zf_equal(zf_predecessor(zf_two), zf_one))
assert(zf_equal(zf_predecessor(zf_predecessor(zf_predecessor(zf_three))), zf_zero))
print("All tests passed! 🥳")

# %% [markdown]
# ## Addition

# %% [markdown]
# **Problem 1.6:** Implement Addition. (Hint: See Classes 17 and 18.)

# %%
def zf_add(a, b):
    """
    Computes the sum of two natural numbers in their set representation.

    Parameters:
    a: A set representation of a natural number.
    b: A set representation of another natural number.

    Returns:
    The sum of a and b in its set representation.
    """
    # TODO: Replace with your implementation
    pass

# %% [markdown]
# If your `zf_add` implementation is correct, the code below should run without errors. (You may want to write your own testing code that uses zf_stringify to examine the outputs if your implementation is failing these tests.)

# %%
# If zf_add is correctly implemented, this cell should run without errors
assert zf_equal(zf_add(zf_two, zf_zero), zf_two)
assert zf_equal(zf_add(zf_zero, zf_two), zf_two)
assert zf_equal(zf_add(zf_one, zf_one), zf_two)
assert zf_equal(zf_add(zf_two, zf_two), zf_four)
print("All tests passed! 🥳")

# %% [markdown]
# # Part 2: Well Ordering

# %% [markdown]
# For this part, you will define a function to determine if a finite set is well ordered or not by a given comparator and equality operation. Your code should work for any set, including sets of Natural Numbers (as defined above), as well as sets of any Python objects where the comparator and equality operation are defined and satisfy the definition of an ordering.
#
# ## Powerset
#
# The first step is to define a function to create the powerset of a set. (Recall that the definition of well ordered is that every non-empty subset of the set has a minimum, so we will be using the powerset definition to get a list of all of the subsets of the input set.)
#
# **Problem 2.1.** Complete the definition of the powerset function.

# %%
def powerset(s):
    """
    Computes the powerset of a given set.

    Parameters:
    s (frozenset): A set.

    Returns:
    A frozenset containing all subsets of s, each represented as a frozenset.
    """
    # TODO: Implement this function
    pass

# %% [markdown]
# Here's a cell to use for testing your powerset implementation:

# %%
print(powerset(frozenset([0, 1, 2])))

# %% [markdown]
# Once your implementation is correct, the following code should run without any errors.

# %%
assert len(powerset(frozenset())) == 1
assert frozenset() in powerset(frozenset())
assert len(powerset(frozenset([0, 1, 2]))) == 8
assert frozenset() in powerset(frozenset([0, 1, 2]))
assert len([s for s in powerset(frozenset([0, 1, 2])) if 0 in s]) == 4
assert len([s for s in powerset(frozenset([0, 1, 2])) if 1 in s]) == 4
assert len([s for s in powerset(frozenset([0, 1, 2])) if 2 in s]) == 4
assert frozenset(["a", "b", "c"]) == frozenset(["b", "a", "c"])
print("All tests passed! 🥳")

# %% [markdown]
# ## Well Ordered
#
# Define a function `is_well_ordered` that takes as input a set, a comparator function, and an equality function, and returns a Boolean indicating if the input set is well ordered.
#
# Don't worry about efficiency (your definition should be correct (in theory) for any set, but it is okay if your implementation won't run in practice on gigantic sets with cardinalities above, say, 5).

# %%
def is_well_ordered(s, comparator, equality):
    """
    Determines whether a set is well-ordered under a given comparator.

    Parameters:
    s: A set.
    comparator: A function that takes two elements and returns True
                if the first is "less than" the second, otherwise False.
    equality:   A function that takes two elements and returns True
                if the first is "equal to" the second, otherwise False.

    The comparator and equality test must be defined for all pairs of
    elements in s, and should satisfy the properties of an ordering.

    Returns:
    True if s is well-ordered under the given comparator, otherwise False.
    """
    for ts in powerset(s):
      # TODO: Complete the implementation of is_well_ordered
      pass

# %% [markdown]
# If your implementation is correct, all of the code below should run without errors.

# %%
# If is_well_ordered is correctly implemented, this cell should run without errors
assert is_well_ordered(frozenset(range(5)), lambda a, b: a < b, lambda a, b: a == b)
assert is_well_ordered(frozenset(range(0, 10, 2)), lambda a, b: a < b, lambda a, b: a == b)
assert not is_well_ordered(frozenset(range(-3, 3)), lambda a, b: abs(a) < abs(b), lambda a, b: a == b)
# Note: I used Claude 3.7 to generate the test set (https://poe.com/s/w1PHrmNtpNDi3rqt8Sr7)
assert not is_well_ordered(frozenset(["Bananarama McPeelface", "Sir Kiwi von Fuzzington",
                                     "Lady Grapenstein", "Señor Mango Magnifico",
                                     "The Honorable Pineapple Bottomsworth"]),
                           lambda a, b: a[0] < b[0],
                           lambda a, b: len(a) == len(b))
# ... and the emojis: https://poe.com/s/4MhAPxKNNjRO65nNzTjA
print("All tests passed! 🥇 ⭐ 🎊 👑 🏅 🌈 💎 🦄 🍾 🤩 ✨ 💫 🏁 💰 🔝 🌠 🦸 🧠 🍀 🧿")

# %% [markdown]
# # Part 3: Open
#
# For part 3, you can do anything you want that builds upon the natural numbers and well ordering definitions here.
#
# A few ideas:
# - Make a more efficient `is_well_ordered` implementation, that works on larger sets without crashing Google.
# - Define a Python class for our natural number representation and use the [functools @total_ordering decorator](https://docs.python.org/3/library/functools.html) so built-in procedures like `sort` and `max` work on it.
# - Define real numbers using sets. (This is challenging, but would be impressive! See https://en.wikipedia.org/wiki/Dedekind_cut and https://math.stackexchange.com/questions/62852/in-set-theory-how-are-real-numbers-represented-as-sets).

# %% [markdown]
# #End of Jupyter Notebook for Problem Set ω
#
# Remember to submit this notebook on Gradescope for Problem Set Omega and update the Collaborators and resources section.
